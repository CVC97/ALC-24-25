# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# function to process gromacs files
def process_gromacs_file(gromacs_file, skiprows):
    list_of_rows = []
    for i_row, line in enumerate(open(gromacs_file)):
        if i_row >= skiprows:
            list_of_rows.append(np.array([*line.split()], dtype = float))
    return np.array(list_of_rows)

# %%
# data processing

# 270 K
pmf_rgyr_270K_data = process_gromacs_file("data/270K/pmf-rg.xvg", 33)
pmf_dist_270K_data = process_gromacs_file("data/270K/pmf-dist.xvg", 33)
rgyr_dist_270K_data = process_gromacs_file("data/270K/xy-rg-dist.xvg", 33)
rgyr_epot_270K_data = process_gromacs_file("data/270K/xy-rg-potential.xvg", 33)


# 300 K - 10 kJ/mol bond angle spring constant
pmf_rgyr_300K_10kJ_data = process_gromacs_file("data/300K_10kJ/pmf-rg.xvg", 33)
pmf_dist_300K_10kJ_data = process_gromacs_file("data/300K_10kJ/pmf-dist.xvg", 33)
rgyr_dist_300K_10kJ_data = process_gromacs_file("data/300K_10kJ/xy-rg-dist.xvg", 33)
rgyr_epot_300K_10kJ_data = process_gromacs_file("data/300K_10kJ/xy-rg-potential.xvg", 33)

angle_distribution_300K_10kJ_data = process_gromacs_file("data/300K_10kJ/angdist.xvg", 33)


# 300 K - 35 kJ/mol bond angle spring constant
pmf_rgyr_300K_35kJ_data = process_gromacs_file("data/300K_35kJ/pmf-rg.xvg", 33)
pmf_dist_300K_35kJ_data = process_gromacs_file("data/300K_35kJ/pmf-dist.xvg", 33)
rgyr_dist_300K_35kJ_data = process_gromacs_file("data/300K_35kJ/xy-rg-dist.xvg", 33)
rgyr_epot_300K_35kJ_data = process_gromacs_file("data/300K_35kJ/xy-rg-potential.xvg", 33)

angle_distribution_300K_35kJ_data = process_gromacs_file("data/300K_35kJ/angdist.xvg", 33)

# 300 K - 45 kJ/mol bond angle spring constant
pmf_rgyr_300K_45kJ_data = process_gromacs_file("data/300K_45kJ/pmf-rg.xvg", 33)
pmf_dist_300K_45kJ_data = process_gromacs_file("data/300K_45kJ/pmf-dist.xvg", 33)
rgyr_dist_300K_45kJ_data = process_gromacs_file("data/300K_45kJ/xy-rg-dist.xvg", 33)
rgyr_epot_300K_45kJ_data = process_gromacs_file("data/300K_45kJ/xy-rg-potential.xvg", 33)

angle_distribution_300K_45kJ_data = process_gromacs_file("data/300K_45kJ/angdist.xvg", 33)


# 330 K
pmf_rgyr_330K_data = process_gromacs_file("data/330K/pmf-rg.xvg", 33)
pmf_dist_330K_data = process_gromacs_file("data/330K/pmf-dist.xvg", 33)
rgyr_dist_330K_data = process_gromacs_file("data/330K/xy-rg-dist.xvg", 33)
rgyr_epot_330K_data = process_gromacs_file("data/330K/xy-rg-potential.xvg", 33)


# 400 K
pmf_rgyr_400K_data = process_gromacs_file("data/400K/pmf-rg.xvg", 33)
pmf_dist_400K_data = process_gromacs_file("data/400K/pmf-dist.xvg", 33)
rgyr_dist_400K_data = process_gromacs_file("data/400K/xy-rg-dist.xvg", 33)
rgyr_epot_400K_data = process_gromacs_file("data/400K/xy-rg-potential.xvg", 33)


# entropic spring
pmf_dist_espring_data = process_gromacs_file("data/espring/pmf-dist.xvg", 33)

# %% [markdown]
# ## (a) Free Energy G along Order Paramters $R_\mathrm{gyr}$ and L

# %%
fig, ax = plt.subplots(1, 2, figsize=( 15,5))

ax[0].set_xlabel(r'radius of gyration $R_\mathrm{gyr}$ in nm')
ax[0].set_ylabel(r'free energy $G(R_\mathrm{gyr})$ in kJ/mol')
ax[0].grid()
ax[0].grid(which='minor', color = '#999999', alpha = 0.2, linestyle = '-')
ax[0].minorticks_on()

# ax[0].plot(pmf_rgyr_270K_data[:,0], pmf_rgyr_270K_data[:,1], color = 'blue', alpha = 0.5, linewidth = 2, label = r'$T=270\,\mathrm{K}$')
ax[0].plot(pmf_rgyr_300K_35kJ_data[:,0], pmf_rgyr_300K_35kJ_data[:,1], color = 'xkcd:red pink', alpha = 0.5, linewidth = 2, label = r'$T=300\,\mathrm{K}$')
# ax[0].plot(pmf_rgyr_330K_data[:,0], pmf_rgyr_330K_data[:,1], color = 'black', alpha = 0.5, linewidth = 2, label = r'$T=330\,\mathrm{K}$')
# ax[0].plot(pmf_rgyr_400K_data[:,0], pmf_rgyr_400K_data[:,1], color = 'black', alpha = 1, linewidth = 2, label = r'$T=400\,\mathrm{K}$')

ax[0].legend()
ax[0].legend(loc="upper left")


ax[1].set_xlabel(r'end-to-end distance $L$ in nm')
ax[1].set_ylabel(r'free energy $G(L)$ in kJ/mol')
ax[1].grid()
ax[1].grid(which='minor', color = '#999999', alpha = 0.2, linestyle = '-')
ax[1].minorticks_on()

# ax[1].plot(pmf_dist_270K_data[:,0], pmf_dist_270K_data[:,1], color = 'blue', alpha = 0.5, linewidth = 2, label = r'$T=270\,\mathrm{K}$')
ax[1].plot(pmf_dist_300K_35kJ_data[:,0], pmf_dist_300K_35kJ_data[:,1], color = 'xkcd:red pink', alpha = 0.5, linewidth = 2, label = r'$T=300\,\mathrm{K}$')
# ax[1].plot(pmf_dist_330K_data[:,0], pmf_dist_330K_data[:,1], color = 'black', alpha = 0.5, linewidth = 2, label = r'$T=330\,\mathrm{K}$')
# ax[1].plot(pmf_dist_400K_data[:,0], pmf_dist_400K_data[:,1], color = 'black', alpha = 1, linewidth = 2, label = r'$T=400\,\mathrm{K}$')

ax[1].legend()
ax[1].legend(loc="upper left")

plt.savefig('BK.MDS_visualizations/aa_G_over_RgyrL.pdf', facecolor = 'white', bbox_inches='tight')
plt.savefig('BK.MDS_visualizations/aa_G_over_RgyrL.pgf', facecolor = 'white', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## (a) End-to-End Distance / Potential Energy over $R_\mathrm{gyr}$

# %%
fig, ax = plt.subplots(1, 2, figsize=( 15,5))

ax[0].set_xlabel(r'radius of gyration $R_\mathrm{gyr}$ in nm')
ax[0].set_ylabel(r'end-to-end distance $L$ in nm')
ax[0].grid()
ax[0].grid(which='minor', color = '#999999', alpha = 0.2, linestyle = '-')
ax[0].minorticks_on()

# ax[0].scatter(rgyr_dist_270K_data[:,0], rgyr_dist_270K_data[:,1], color = 'blue', alpha = 0.5, s = 4, label = r'$T=270\,\mathrm{K}$')
ax[0].scatter(rgyr_dist_300K_35kJ_data[:,0], rgyr_dist_300K_35kJ_data[:,1], color = 'xkcd:red pink', alpha = 0.5, s = 4, label = r'$T=300\,\mathrm{K}$')
# ax[0].scatter(rgyr_dist_330K_data[:,0], rgyr_dist_330K_data[:,1], color = 'black', alpha = 0.5, s = 4, label = r'$T=330\,\mathrm{K}$')
# ax[0].scatter(rgyr_dist_400K_data[:,0], rgyr_dist_400K_data[:,1], color = 'black', alpha = 1, s = 4, label = r'$T=400\,\mathrm{K}$')

ax[0].legend()
ax[0].legend(loc="upper left")


ax[1].set_xlabel(r'radius of gyration $R_\mathrm{gyr}$ in nm')
ax[1].set_ylabel(r'potential energy $H(R_\mathrm{gyr})$ in kJ/mol')
ax[1].grid()
ax[1].grid(which='minor', color = '#999999', alpha = 0.2, linestyle = '-')
ax[1].minorticks_on()

# ax[1].scatter(rgyr_epot_270K_data[:,0], rgyr_epot_270K_data[:,1], color = 'blue', alpha = 0.5, s = 4, label = r'$T=270\,\mathrm{K}$')
ax[1].scatter(rgyr_epot_300K_35kJ_data[:,0], rgyr_epot_300K_35kJ_data[:,1], color = 'xkcd:red pink', alpha = 0.5, s = 4, label = r'$T=300\,\mathrm{K}$')
# ax[1].scatter(rgyr_epot_330K_data[:,0], rgyr_epot_330K_data[:,1], color = 'black', alpha = 0.5, s = 4, label = r'$T=330\,\mathrm{K}$')
# ax[1].scatter(rgyr_epot_400K_data[:,0], rgyr_epot_400K_data[:,1], color = 'black', alpha = 1, s = 4, label = r'$T=400\,\mathrm{K}$')

ax[1].legend()
ax[1].legend(loc="upper left")

plt.savefig('BK.MDS_visualizations/aa_LV_over_Rgyr.pdf', facecolor = 'white', bbox_inches='tight')
plt.savefig('BK.MDS_visualizations/aa_LV_over_Rgyr.jpg', facecolor = 'white', bbox_inches='tight')
plt.savefig('BK.MDS_visualizations/aa_LV_over_Rgyr.pgf', facecolor = 'white', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## (b) Free Energy Profiles over T

# %%
fig, ax = plt.subplots(1, 2, figsize=( 15,5))

ax[0].set_xlabel(r'radius of gyration $R_\mathrm{gyr}$ in nm')
ax[0].set_ylabel(r'free energy $G(R_\mathrm{gyr})$ in kJ/mol')
ax[0].grid()
ax[0].grid(which='minor', color = '#999999', alpha = 0.2, linestyle = '-')
ax[0].minorticks_on()

ax[0].plot(pmf_rgyr_270K_data[:,0], pmf_rgyr_270K_data[:,1], color = 'blue', alpha = 0.5, linewidth = 2, label = r'$T=270\,\mathrm{K}$')
ax[0].plot(pmf_rgyr_300K_35kJ_data[:,0], pmf_rgyr_300K_35kJ_data[:,1], color = 'xkcd:red pink', alpha = 0.5, linewidth = 2, label = r'$T=300\,\mathrm{K}$')
ax[0].plot(pmf_rgyr_330K_data[:,0], pmf_rgyr_330K_data[:,1], color = 'black', alpha = 0.5, linewidth = 2, label = r'$T=330\,\mathrm{K}$')
ax[0].plot(pmf_rgyr_400K_data[:,0], pmf_rgyr_400K_data[:,1], color = 'black', alpha = 1, linewidth = 2, label = r'$T=400\,\mathrm{K}$')

ax[0].legend()
ax[0].legend(loc="upper left")


ax[1].set_xlabel(r'end-to-end distance $L$ in nm')
ax[1].set_ylabel(r'free energy $G(L)$ in kJ/mol')
ax[1].grid()
ax[1].grid(which='minor', color = '#999999', alpha = 0.2, linestyle = '-')
ax[1].minorticks_on()

ax[1].plot(pmf_dist_270K_data[:,0], pmf_dist_270K_data[:,1], color = 'blue', alpha = 0.5, linewidth = 2, label = r'$T=270\,\mathrm{K}$')
ax[1].plot(pmf_dist_300K_35kJ_data[:,0], pmf_dist_300K_35kJ_data[:,1], color = 'xkcd:red pink', alpha = 0.5, linewidth = 2, label = r'$T=300\,\mathrm{K}$')
ax[1].plot(pmf_dist_330K_data[:,0], pmf_dist_330K_data[:,1], color = 'black', alpha = 0.5, linewidth = 2, label = r'$T=330\,\mathrm{K}$')
ax[1].plot(pmf_dist_400K_data[:,0], pmf_dist_400K_data[:,1], color = 'black', alpha = 1, linewidth = 2, label = r'$T=400\,\mathrm{K}$')

ax[1].legend()
ax[1].legend(loc="upper left")

plt.savefig('BK.MDS_visualizations/bb_G_vary_T.pdf', facecolor = 'white', bbox_inches='tight')
plt.savefig('BK.MDS_visualizations/bb_G_vary_T.pgf', facecolor = 'white', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## (c) Free Energy Profiles over Bond Angule Energy

# %%
fig, ax = plt.subplots(1, 2, figsize=( 15,5))

ax[0].set_xlabel(r'radius of gyration $R_\mathrm{gyr}$ in nm')
ax[0].set_ylabel(r'free energy $G(R_\mathrm{gyr})$ in kJ/mol')
ax[0].grid()
ax[0].grid(which='minor', color = '#999999', alpha = 0.2, linestyle = '-')
ax[0].minorticks_on()

ax[0].plot(pmf_rgyr_300K_10kJ_data[:,0], pmf_rgyr_300K_10kJ_data[:,1], color = 'blue', alpha = 0.5, linewidth = 2, label = r'$k_\mathrm{angle}=10\,\mathrm{kJ}$')
ax[0].plot(pmf_rgyr_300K_35kJ_data[:,0], pmf_rgyr_300K_35kJ_data[:,1], color = 'xkcd:red pink', alpha = 0.5, linewidth = 2, label = r'$k_\mathrm{angle}=35\,\mathrm{kJ}$')
ax[0].plot(pmf_rgyr_300K_45kJ_data[:,0], pmf_rgyr_300K_45kJ_data[:,1], color = 'black', alpha = 0.5, linewidth = 2, label = r'$k_\mathrm{angle}=45\,\mathrm{kJ}$')

ax[0].legend()
ax[0].legend(loc="upper left")


ax[1].set_xlabel(r'end-to-end distance $L$ in nm')
ax[1].set_ylabel(r'free energy $G(L)$ in kJ/mol')
ax[1].grid()
ax[1].grid(which='minor', color = '#999999', alpha = 0.2, linestyle = '-')
ax[1].minorticks_on()

ax[1].plot(pmf_dist_300K_10kJ_data[:,0], pmf_dist_300K_10kJ_data[:,1], color = 'blue', alpha = 0.5, linewidth = 2, label = r'$k_\mathrm{angle}=10\,\mathrm{kJ}$')
ax[1].plot(pmf_dist_300K_35kJ_data[:,0], pmf_dist_300K_35kJ_data[:,1], color = 'xkcd:red pink', alpha = 0.5, linewidth = 2, label = r'$k_\mathrm{angle}=35\,\mathrm{kJ}$')
ax[1].plot(pmf_dist_300K_45kJ_data[:,0], pmf_dist_300K_45kJ_data[:,1], color = 'black', alpha = 0.5, linewidth = 2, label = r'$k_\mathrm{angle}=45\,\mathrm{kJ}$')

ax[1].legend()
ax[1].legend(loc="upper left")

plt.savefig('BK.MDS_visualizations/cc_G_vary_k_angle.pdf', facecolor = 'white', bbox_inches='tight')
plt.savefig('BK.MDS_visualizations/cc_G_vary_k_angle.pgf', facecolor = 'white', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## (c) Angle Distribution over Bond Angle Energy

# %%
fig, ax = plt.subplots(figsize=(7.5, 5))

ax.set_xlabel(r'bond angle $\Theta$ in degrees')
ax.set_ylabel(r'frequency of occurrence')
ax.grid()
ax.grid(which='minor', color = '#999999', alpha = 0.2, linestyle = '-')
ax.minorticks_on()

ax.plot(angle_distribution_300K_10kJ_data[:,0], angle_distribution_300K_10kJ_data[:,1], color = 'blue', alpha = 0.5, linewidth = 2, label = r'$k_\mathrm{angle}=10\,\mathrm{kJ}$')
ax.plot(angle_distribution_300K_35kJ_data[:,0], angle_distribution_300K_35kJ_data[:,1], color = 'xkcd:red pink', alpha = 0.5, linewidth = 2, label = r'$k_\mathrm{angle}=35\,\mathrm{kJ}$')
ax.plot(angle_distribution_300K_45kJ_data[:,0], angle_distribution_300K_45kJ_data[:,1], color = 'black', alpha = 0.5, linewidth = 2, label = r'$k_\mathrm{angle}=45\,\mathrm{kJ}$')

ax.legend()
ax.legend(loc="upper left")

plt.savefig('BK.MDS_visualizations/cc_angle_distribution_vary_k_angle.pdf', facecolor = 'white', bbox_inches='tight')
plt.savefig('BK.MDS_visualizations/cc_angle_distribution_vary_k_angle.pgf', facecolor = 'white', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## (d) Entropic Spring: Free Energy G over End-to_End Distance L

# %%
fig, ax = plt.subplots(figsize=(7.5, 5))

ax.set_xlabel(r'end-to-end distance $L$ in nm')
ax.set_ylabel(r'free energy $G(L)$ in kJ/mol')
ax.grid()
ax.grid(which='minor', color = '#999999', alpha = 0.2, linestyle = '-')
ax.minorticks_on()

# ax.plot(pmf_dist_300K_35kJ_data[:,0], pmf_dist_300K_35kJ_data[:,1], color = 'xkcd:red pink', alpha = 0.5, linewidth = 2, label = r'standard simulation with vdW and bond energies')
ax.plot(pmf_dist_espring_data[:,0], pmf_dist_espring_data[:,1], color = 'black', alpha = 1, linewidth = 2, label = r'entropic spring')

ax.legend()
ax.legend(loc="upper left")

plt.savefig('BK.MDS_visualizations/dd_G_over_L.pdf', facecolor = 'white', bbox_inches='tight')
plt.savefig('BK.MDS_visualizations/dd_G_over_L.pgf', facecolor = 'white', bbox_inches='tight')
plt.show()
